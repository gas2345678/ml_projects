# %% [markdown]
# # Amazon products analyzer
#
# This project focus on showing a demo of how text processing works and a real scenarios which can be approached for this operations.
#
# In this case, we will focus on Amazon products reviews

# %%
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize

# %% [markdown]
# We use a sample text for the tokenize task

# %%
text= "Hello everyone, welcome to the world of Natural Language Processing. Let's explore tokenization."

# %%
tokenized_text = word_tokenize(text,language="english",preserve_line=True)
print(tokenized_text)
# Out:
# ['Hello', 'everyone', ',', 'welcome', 'to', 'the', 'world', 'of', 'Natural', 'Language', 'Processing.', 'Let', "'s", 'explore', 'tokenization', '.']

# %% [markdown]
# Now, we will show a demo of a sentiment analysis for a text sample, identifying positives or negatives feelings.

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

sia = SentimentIntensityAnalyzer()

# %%
sample_positive_text = "I love programming! It's so much fun and rewarding."
sentiment_scores = sia.polarity_scores(sample_positive_text)
print(sentiment_scores)
# Out:
# {'neg': 0.0, 'neu': 0.304, 'pos': 0.696, 'compound': 0.9094}

# %%
sample_text = "I hate bugs! They are so frustrating and annoying."
sentiment_scores = sia.polarity_scores(sample_text)
print(sentiment_scores)
# Out:
# {'neg': 0.681, 'neu': 0.319, 'pos': 0.0, 'compound': -0.8933}

# %% [markdown]
# These operations are useful in a scenario like products or movie reviews to gains insights about our business critics.

# %% [markdown]
# We will perform a demostration for different Amazon products.

# %% [markdown]
# We will use a dataframe

# %%
#Import the necessary libraries
import pandas as pd

# %%
df = pd.read_csv("ml_datasets/Reviews.csv")

# %%
#Drop null values
df = df.dropna()

# %%
df.head(5)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %% [markdown]
# s

# %% [markdown]
# We will focus on the 'Summary' column

# %%
df["Summary"].head(5)
# Out:
# 0    Good Quality Dog Food
# 1        Not as Advertised
# 2    "Delight" says it all
# 3           Cough Medicine
# 4              Great taffy
# Name: Summary, dtype: object

# %% [markdown]
# Now we will get the sentiments results for each critic

# %%
for row in df["Summary"]:
    print(row)
    print(sia.polarity_scores(row))
# Out:
# Good Quality Dog Food
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# Not as Advertised
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# "Delight" says it all
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Cough Medicine
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Great taffy
# {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6249}
# Nice Taffy
# {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# Great!  Just as good as the expensive brands!
# {'neg': 0.0, 'neu': 0.442, 'pos': 0.558, 'compound': 0.8217}
# Wonderful, tasty taffy
# {'neg': 0.0, 'neu': 0.351, 'pos': 0.649, 'compound': 0.5719}
# Yay Barley
# {'neg': 0.0, 'neu': 0.227, 'pos': 0.773, 'compound': 0.5267}
# Healthy Dog Food
# {'neg': 0.0, 'neu': 0.426, 'pos': 0.574, 'compound': 0.4019}
# The Best Hot Sauce in the World
# {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.6369}
# My cats LOVE this "diet" food better than their regular food
# ...

# %% [markdown]
# Now we have the results of each critic.
